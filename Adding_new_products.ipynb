# %%
record={
1001:{"name":"Honey" , "cost":"314" ,"Quantity":"10" ,"Weight":"50" ,"tax":"5"},
1002:{"name":"glucose","cost":"85","Quantity":"20","Weight":"100","tax":"4"},
1003:{"name":"snickers","cost":"99","Quantity":"100" ,"Weight":"70","tax":"5"},
1004:{"name":"parle hide n seek","cost":"72","Quantity":"50","Weight":"50","tax":"10"},
1005:{"name":"butter","cost":"250","Quantity":"25","Weight":"150","tax":"12"},
1006:{"name":"cooking oil","cost":"550","Quantity":"30","Weight":"1","tax":"20"},
1007:{"name":"Eggs","cost":"120","Quantity":"15","Weight":"120","tax":"5"},
1008:{"name":"cheese","cost":"300","Quantity":"40","Weight":"130","tax":"10"},
1009:{"name":"onions","cost":"200","Quantity":"100","Weight":"l","tax":"15"},
1010:{"name":"Garlic","cost":"90","Quantity":"50","Weight":"250","tax":"2"},
1011:{"name":"vegetables","cost":"210","Quantity":"150","Weight":"2","tax":"7"},
1012:{"name":"Yogurt","cost":"170","Quantity":"20","Weight":"2","tax":"5"},
1013:{"name":"nuts","cost":"350","Quantity":"80","Weight":"550","tax":"20"},
1014:{"name":"sugar","cost":"450","Quantity":"150","Weight":"250","tax":"10"},
1015:{"name":"bread","cost":"230","Quantity":"130","Weight":"50","tax":"5"},
1016:{"name":"salt","cost":"220","Quantity":"20","Weight":"150","tax":"10"},
1017:{"name":"blackgram","cost":"750","Quantity":"100","Weight":"1","tax":"10"},
1018:{"name":"redgram","cost":"880","Quantity":"120","Weight":"1.5","tax":"15"},
1019:{"name":"greengram","cost":"850","Quantity":"130","Weight":"2","tax":"20"},
1020:{"name":"pasta","cost":"550","Quantity":"20","Weight":"100","tax":"15"},
1021:{"name":"milk","cost":"50","Quantity":"30","Weight":"2","tax":"20"},
1022:{"name":"fruit","cost":"180","Quantity":"70","Weight":"550","tax":"30"},
1023:{"name":"vinegar","cost":"20","Quantity":"20","Weight":"50","tax":"20"},
1024:{"name":"chocolates","cost":"50","Quantity":"70","Weight":"20","tax":"5"},
1025:{"name":"salty snaks","cost":"80","Quantity":"80","Weight":"80","tax":"10"},
1026:{"name":"chilli powder","cost":"210","Quantity":"110","Weight":"250","tax":"20"},
1027:{"name":"dryfruits","cost":"330","Quantity":"100","Weight":"300","tax":"30"},
1028:{"name":"rice","cost":"1000","Quantity":"150","Weight":"2","tax":"30"},
1029:{"name":"pepper","cost":"50","Quantity":"20","Weight":"100","tax":"10"},
1030:{"name":"breakfast cereal","cost":"550","Quantity":"50","Weight":"20","tax":"5"},
}

# %%
record
# Out:
# {1001: {'Quantity': '10',
#   'Weight': '50',
#   'cost': '314',
#   'name': 'Honey',
#   'tax': '5'},
#  1002: {'Quantity': '20',
#   'Weight': '100',
#   'cost': '85',
#   'name': 'glucose',
#   'tax': '4'},
#  1003: {'Quantity': '100',
#   'Weight': '70',
#   'cost': '99',
#   'name': 'snickers',
#   'tax': '5'},
#  1004: {'Quantity': '50',
#   'Weight': '50',
#   'cost': '72',
#   'name': 'parle hide n seek',
#   'tax': '10'},
#  1005: {'Quantity': '25',
#   'Weight': '150',
#   'cost': '250',
#   'name': 'butter',
#   'tax': '12'},
#  1006: {'Quantity': '30',
#   'Weight': '1',
#   'cost': '550',
#   'name': 'cooking oil',
#   'tax': '20'},
#  1007: {'Quantity': '15',
#   'Weight': '120',
#   'cost': '120',
#   'name': 'Eggs',
#   'tax': '5'},
#  1008: {'Quantity': '40',
#   'Weight': '130',
#   'cost': '300',
#   'name': 'cheese',
#   'tax': '10'},
#  1009: {'Quantity': '100',
#   'Weight': 'l',
#   'cost': '200',
#   'name': 'onions',
#   'tax': '15'},
# ...

# %%
import json

# %%
js=json.dumps(record)

# %%
js
# Out:
# '{"1001": {"name": "Honey", "cost": "314", "Quantity": "10", "Weight": "50", "tax": "5"}, "1002": {"name": "glucose", "cost": "85", "Quantity": "20", "Weight": "100", "tax": "4"}, "1003": {"name": "snickers", "cost": "99", "Quantity": "100", "Weight": "70", "tax": "5"}, "1004": {"name": "parle hide n seek", "cost": "72", "Quantity": "50", "Weight": "50", "tax": "10"}, "1005": {"name": "butter", "cost": "250", "Quantity": "25", "Weight": "150", "tax": "12"}, "1006": {"name": "cooking oil", "cost": "550", "Quantity": "30", "Weight": "1", "tax": "20"}, "1007": {"name": "Eggs", "cost": "120", "Quantity": "15", "Weight": "120", "tax": "5"}, "1008": {"name": "cheese", "cost": "300", "Quantity": "40", "Weight": "130", "tax": "10"}, "1009": {"name": "onions", "cost": "200", "Quantity": "100", "Weight": "l", "tax": "15"}, "1010": {"name": "Garlic", "cost": "90", "Quantity": "50", "Weight": "250", "tax": "2"}, "1011": {"name": "vegetables", "cost": "210", "Quantity": "150", "Weight": "2", "tax
# ...

# %%
fd=open("record.json",'w')
fd.write(js)
fd.close()

# %%
import json
fd=open("record.json",'r')
r=fd.read()
fd.close()
records=json.loads(r)

# %%
record
# Out:
# {'1001': {'Quantity': '10',
#   'Weight': '50',
#   'cost': '314',
#   'name': 'Honey',
#   'tax': '5'},
#  '1002': {'Quantity': '20',
#   'Weight': '100',
#   'cost': '85',
#   'name': 'glucose',
#   'tax': '4'},
#  '1003': {'Quantity': '100',
#   'Weight': '70',
#   'cost': '99',
#   'name': 'snickers',
#   'tax': '5'},
#  '1004': {'Quantity': '50',
#   'Weight': '50',
#   'cost': '72',
#   'name': 'parle hide n seek',
#   'tax': '10'},
#  '1005': {'Quantity': '25',
#   'Weight': '150',
#   'cost': '250',
#   'name': 'butter',
#   'tax': '12'},
#  '1006': {'Quantity': '30',
#   'Weight': '1',
#   'cost': '550',
#   'name': 'cooking oil',
#   'tax': '20'},
#  '1007': {'Quantity': '15',
#   'Weight': '120',
#   'cost': '120',
#   'name': 'Eggs',
#   'tax': '5'},
#  '1008': {'Quantity': '40',
#   'Weight': '130',
#   'cost': '300',
#   'name': 'cheese',
#   'tax': '10'},
#  '1009': {'Quantity': '100',
#   'Weight': 'l',
#   'cost': '200',
#   'name': 'onions',
#   'tax': '15'},
# ...

# %% [markdown]
# **Add New Item To Inventory**

# %%
prod_id=int(input("Enter product id:"))
name=input("Enter product name")
pr=int(input("Enter cost"))
qn=int(input("enter  Quantity"))
w=int(input("Enter weight"))
tax=int(input("Enter tax"))

record[prod_id] = {'name':name, 'cost':pr, 'Quantity':qn, 'Weight':w,'tax':tax}

js=json.dumps(record)

fd=open('record.json','w')
fd.write(js)
fd.close()
# Out:
# Enter product id:1031
# Enter product namelittile hearts
# Enter cost20
# enter  Quantity10
# Enter weight20
# Enter tax5

# %%
record
# Out:
# {'1001': {'Quantity': '10',
#   'Weight': '50',
#   'cost': '314',
#   'name': 'Honey',
#   'tax': '5'},
#  '1002': {'Quantity': '20',
#   'Weight': '100',
#   'cost': '85',
#   'name': 'glucose',
#   'tax': '4'},
#  '1003': {'Quantity': '100',
#   'Weight': '70',
#   'cost': '99',
#   'name': 'snickers',
#   'tax': '5'},
#  '1004': {'Quantity': '50',
#   'Weight': '50',
#   'cost': '72',
#   'name': 'parle hide n seek',
#   'tax': '10'},
#  '1005': {'Quantity': '25',
#   'Weight': '150',
#   'cost': '250',
#   'name': 'butter',
#   'tax': '12'},
#  '1006': {'Quantity': '30',
#   'Weight': '1',
#   'cost': '550',
#   'name': 'cooking oil',
#   'tax': '20'},
#  '1007': {'Quantity': '15',
#   'Weight': '120',
#   'cost': '120',
#   'name': 'Eggs',
#   'tax': '5'},
#  '1008': {'Quantity': '40',
#   'Weight': '130',
#   'cost': '300',
#   'name': 'cheese',
#   'tax': '10'},
#  '1009': {'Quantity': '100',
#   'Weight': 'l',
#   'cost': '200',
#   'name': 'onions',
#   'tax': '15'},
# ...

# %%
records
# Out:
# {'1001': {'Quantity': '10',
#   'Weight': '50',
#   'cost': '314',
#   'name': 'Honey',
#   'tax': '5'},
#  '1002': {'Quantity': '20',
#   'Weight': '100',
#   'cost': '85',
#   'name': 'glucose',
#   'tax': '4'},
#  '1003': {'Quantity': '100',
#   'Weight': '70',
#   'cost': '99',
#   'name': 'snickers',
#   'tax': '5'},
#  '1004': {'Quantity': '50',
#   'Weight': '50',
#   'cost': '72',
#   'name': 'parle hide n seek',
#   'tax': '10'},
#  '1005': {'Quantity': '25',
#   'Weight': '150',
#   'cost': '250',
#   'name': 'butter',
#   'tax': '12'},
#  '1006': {'Quantity': '30',
#   'Weight': '1',
#   'cost': '550',
#   'name': 'cooking oil',
#   'tax': '20'},
#  '1007': {'Quantity': '15',
#   'Weight': '120',
#   'cost': '120',
#   'name': 'Eggs',
#   'tax': '5'},
#  '1008': {'Quantity': '40',
#   'Weight': '130',
#   'cost': '300',
#   'name': 'cheese',
#   'tax': '10'},
#  '1009': {'Quantity': '100',
#   'Weight': 'l',
#   'cost': '200',
#   'name': 'onions',
#   'tax': '15'},
# ...
